# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# # Identificación de variables categóricas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KevinRC55/Proyecto-de-Python-BEDU/main/RNPEDFC_Final.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    anio       fecha      hora  dias_desaparecido           entidad  \
# 0  2012  2012-03-18  05:00:00               2234            Sonora
# 1  2007  2007-02-05  02:00:26               4102  Estado De Mexico
# 2  2009  2009-03-14  08:30:54               3334  Estado De Mexico
# 3  2006  2006-12-23  08:00:28               4146  Estado De Mexico
# 4  2008  2008-01-11  12:00:17               3762  Estado De Mexico
#
#              municipio            localidad             coordenadas  \
# 0              Navojoa              Navojoa  27.069053, -109.439423
# 1       Valle De Bravo       Valle De Bravo   19.16368, -100.134684
# 2               Chalco               Chalco     19.266337, -98.8978
# 3  Tlalnepantla De Baz  Tlalnepantla De Baz   19.547512, -99.193851
# 4               Toluca               Toluca        18.078, -91.6552
#
#   nacionalidad    sexo  edad  estatura complexion  \
# 0     Mexicana   Mujer     7       1.1    Delgada
# 1     Mexicana   Mujer     4       1.1    Delgada
# 2     Mexicana  Hombre     6       1.1    Delgada
# 3     Mexicana  Hombre    10       1.1    Delgada
# 4     Mexicana  Hombre     4       1.1    Delgada
#
#                                   senas_particulares discapacidad  \
# 0  Tiene Una Cicatriz En La Rodilla Izquierda Por...      Ninguno
# 1                                    No Especificado      Ninguno
# 2  Manchas, Parte Superior De Pierna Derecha, Cic...      Ninguno
# 3  Lunares, A La Altura De La Cinturaforma De Man...      Ninguno
# 4                                    No Especificado      Ninguno
#
#         dependecia_origen
# 0            FGE - Sonora
# 1  FGJ - Estado De Mexico
# 2  FGJ - Estado De Mexico
# 3  FGJ - Estado De Mexico
# 4  FGJ - Estado De Mexico

# %% [markdown]
# En el proyecto anterior ya habíamos identificado las variables categóricas de nuestro dataset, las cuales fueron las siguientes:
# | Variable | Tipo |
# | -------  | ---- |
# | Pais en que se le vio por ultima vez         | Categórico (`MEXICO`) |
# | Entidad en que se le vio por ultima vez      | Categórico (valores de `entidad`) |
# | Municipio en que se le vio por ultima vez    | Categórica (valores de `municipio`) |
# | Localidad en que se le vio por ultima vez    | Categórica (valores de `localidad`) |
# | Nacionalidad                                 | Categórica (valores de `nacionalidad`) |
# | Complexion                                   | Categórica (`Delgada`, `Mediana`, `NO ESPECIFICADA`, `Obesa`, `Robusta`) |
# | Sexo                                         | Categórica (`Hombre`, `Mujer`) |
# | Estatura                                     | Numérico float64 (valores en metros) |
# | Edad                                         | Numérico int64 (`1` a `103`) |
# | Etnia                                        | Categórica (valores de  `etnia`)|
# | Discapacidad                                 | Categórica (`Autismo`, `Ninguno`, `NO ESPECIFICADO`, `Sindrome de Down`) |
# | Dependencia que envio la informacion         | Categórica (valores de `dependencia_origen`) |

# %% [markdown]
# Obtenemos el conteo de frecuencias para cada variable categórica.

# %%
counts = df['anio'].value_counts()
ax = sns.barplot(x=counts.index, y=counts)
ax.set_title(f'Conteo de años')
ax.set(ylabel='count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);

# %%
counts = df['entidad'].value_counts()
ax = sns.barplot(x=counts.index, y=counts)
ax.set_title(f'Conteo de entidad')
ax.set(ylabel='count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);

# %%
counts = df['nacionalidad'].value_counts()
ax = sns.barplot(x=counts.index, y=counts)
ax.set_title(f'Conteo de nacionalidad')
ax.set(ylabel='count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);

# %%
counts = df['sexo'].value_counts()
ax = sns.barplot(x=counts.index, y=counts)
ax.set_title(f'Conteo de sexo')
ax.set(ylabel='count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);

# %%
counts = df['complexion'].value_counts()
ax = sns.barplot(x=counts.index, y=counts)
ax.set_title(f'Conteo de complexion')
ax.set(ylabel='count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);

# %%
counts = df['discapacidad'].value_counts()
ax = sns.barplot(x=counts.index, y=counts)
ax.set_title(f'Conteo de discapacidad')
ax.set(ylabel='count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);

# %% [markdown]
# Graficamos el resto de variables:

# %%
pd.crosstab(df['sexo'], df['complexion'])
# Out:
# complexion  Delgada  Mediana  No Especificado  Obesa  Robusta
# sexo
# Hombre         9685     3683             8411    186     4710
# Mujer          3540     1443             2739     48     1456

# %%
pd.crosstab(df['complexion'], df['entidad'])
# Out:
# entidad          Aguascalientes  Baja California  Baja California Sur  \
# complexion
# Delgada                      78              376                   20
# Mediana                      16              118                   11
# No Especificado              97              259                    2
# Obesa                         3                5                    0
# Robusta                      28              107                    6
#
# entidad          Campeche  Chiapas  Chihuahua  Ciudad De Mexico  \
# complexion
# Delgada                19       57        939               318
# Mediana                 1       19        327               121
# No Especificado         7        0        573               188
# Obesa                   0        0          5                 1
# Robusta                 7       32        337                99
#
# entidad          Coahuila De Zaragoza  Colima  Durango  ...  Quintana Roo  \
# complexion                                              ...
# Delgada                           532     345      138  ...            30
# Mediana                           275      35       59  ...            11
# No Especificado                   479      37      122  ...             9
# Obesa                              16       1        1  ...             0
# Robusta                           412     174       95  ...            11
#
# entidad          San Luis Potosi  Sinaloa  Sonora  Tabasco  Tamaulipas  \
# complexion
# Delgada                       15      991     825       20        1792
# Mediana                        7      461     276        6         666
# No Especificado               59     1430     785       31        2172
# Obesa                          1       15      20        0          58
# Robusta                       14      126     244       10        1299
#
# entidad          Tlaxcala  Veracruz  Yucatan  Zacatecas
# complexion
# Delgada                13       189       48        208
# Mediana                 5        98       24        100
# No Especificado         0        72        2        103
# Obesa                   0         7        2          4
# Robusta                 6       154       23         95
#
# [5 rows x 32 columns]

# %%
pd.crosstab(df['edad'], df['complexion'])
# Out:
# complexion  Delgada  Mediana  No Especificado  Obesa  Robusta
# edad
# 1                36       30               57      0       29
# 2                52       21               27      0       21
# 3                62       31               30      0       15
# 4                66       19               20      0       10
# 5                70       13               17      1        9
# ...             ...      ...              ...    ...      ...
# 96                0        1                0      0        1
# 97                2        0                2      0        0
# 98                0        0                2      0        0
# 99                0        1                0      0        0
# 103               0        1                0      0        0
#
# [99 rows x 5 columns]

# %%
sns.boxplot(x=df['edad']);

# %%
sns.boxplot(x=df['estatura']);

# %%
sns.boxplot(x=df['anio']);

# %%
sns.violinplot(x=df['edad']);

# %%
sns.violinplot(x=df['anio']);

# %%
sns.violinplot(x=df['estatura']);
